# %%
import numpy as np 
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set(color_codes=True)
# %matplotlib inline

# %%
# Read the dataset file using pandas
df = pd.read_csv('iris.data')

# %%
# Print the first 5 records of the dataset
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
pd.read_csv?

# %%
pd.read_csv('iris.data',header=-1)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
col_name = ['sepal length','sepal width','petal length','petal width','class']

# %%
df.columns = col_name
# Show me the top 5 records of the dataset now
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
# iris data from seaborn
# Now load the dataset that we got
iris = sb.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
# Using the pairplot to get the appropriate visualisation and intuition
sb.pairplot?

# %%
sb.pairplot(iris,hue='species',size=3,aspect=1)

# %%
# Histo visualize
sb.hist?
# Out:
# Object `sb.hist` not found.

# %%
iris.hist?

# %%
iris.hist(edgecolor='black',linewidth=1.2,figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EB0D6FB668>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EB0DEB0F98>]], dtype=object)

# %%
plt.show()

# %%
# Plot the figure
plt.figure(figsize=(12,8))

# %%
plt.subplot(2,2,1)
sb.violinplot(x='species',y='sepal_length',data=iris)
plt.subplot(2,2,2)
sb.violinplot(x='species',y='sepal_width',data=iris)
plt.subplot(2,2,3)
sb.violinplot(x='species',y='petal_length',data=iris)
plt.subplot(2,2,4)
sb.violinplot(x='species',y='petal_width',data=iris)

# %%
# Box plot
iris.boxplot(by='species',figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EB0D6DB908>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EB0E389198>]], dtype=object)

# %%
# Using pandas you can plot the scatter matrix
pd.?
# Out:
#   File "<ipython-input-26-c2bcf1751cc5>", line 2
#     pd.?
#        ^
# SyntaxError: invalid syntax

# %%
pd?

# %%
pd.plotting?

# %%
pd.plotting?

# %%
pd?

# %%
pd.plotting.scatter_matrix(iris,figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EB0E731080>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EB0EA64518>]], dtype=object)

# %%
plt.show()

# %%
# Supervised Learning - Simple Linear Regression

# %%
x= 10*np.random.rand(100)

# %%
y = 3*x + np.random.rand(100)

# %%
y = 3*x + np.random.randn(100)

# %%
# Plot the scatter diagram
plt.scatter(x,y)

# %%
from sklearn.linear_regression import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-7d263c4df9df> in <module>()
# ----> 1 from sklearn.linear_regression import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn.linear_regression'

# %%
from sklearn.linear_model import LinearRegression

# %%
# Design the model
model = LinearRegression?

# %%
model = LinearRegression

# %%
model = LinearRegression.?
# Out:
#   File "<ipython-input-41-b46233ee62bc>", line 1
#     model = LinearRegression.?
#                              ^
# SyntaxError: invalid syntax

# %%
model = LinearRegression(fit_intercept=True)

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X = x.reshape(-1,1)
X.shape
# Out:
# (100, 1)

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Predict the labels
model.coef_
# Out:
# array([ 3.02584436])

# %%
model.intercept_
# Out:
# -0.088003356008840683

# %%
mode.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-ed150650dfcc> in <module>()
# ----> 1 mode.intercept_
#
# NameError: name 'mode' is not defined

# %%
model.intercept_
# Out:
# -0.088003356008840683

# %%
# Perform the prediction
x_fit = np.linspace(-1,11)

# %%
X_fit = x_fit.reshape(-1,1)

# %%
y_fit = model.predict(X_fit)

# %%
# Original dataset
plt.scatter(x,y)

# %%
plt.scatter(x_fit,y_fit)
